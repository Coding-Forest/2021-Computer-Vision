# %% [markdown]
# # Lecture 1
#
# **Notes and Reference**
#
# - Stanford University School of Engineering (2017) Lecture 1 | Introduction to Convolutional Neural Networks for Visual Recognition https://www.youtube.com/watch?v=vT1JzLTH4G4&ab_channel=StanfordUniversitySchoolofEngineering

# %% [markdown]
# # History of (Computer) Vision
# Andrew Parker (Australian Zoologist) suggested a theoroy that about 540 m years ago the first animal developed eyes, which is the onset of the development of eyes.
#
# # History of Mechine vision
# Camera Obscura
# - Gemma Frisius (1545)
# - Leonardo Da Vinci (16th century)
# - Hubel & Wiesel (1959)
# - Studied cat brain
#
# Simple cells: response to light orientation
# Complex cells: response to
#
# Block World (Larry Roberts, 1963)
# - Simplify and recognisze shapes.
#
# The Summer Vision Project (Artificial Intelligence Group, 1966)
#
# ---
#
# ## Fundamental problems of vision
# CISCO reports that 70% of internet content traffic consists of videos in 2017.
#
# - Vision (David Marr, MIT Vision Researcher)
#   - Input image - Edge image - 2 and 1/2-D sketch - 3D model
#
# - Pictorial Structure (Fischler and Elschlager, 1973)
# - David Lowe (1987)
#   - Constructed edges to recognise images.
#
# <br>
#
# If object recognition is too hard, we can at least segment it.
#
# - Normalised Cut (Shi & Malik, 1997)
#   - Segment pixels into groups using graph theory algorithm.
# - Real-tiem Face Detection (Viola & Jones, 2001)
#
# - SIFT & Object Recognition (David Lowe, 1999)
#   - Viewpoints
#   - occlusion
#   - lighting
#   - camera angles...
#
# - Spatial Pyramid Matching (Lazebnik, Schmid & Ponce, 2006)
# - Histogram of Gradients (HoG) (Dalal & Triggs, 2005)
# - Deformable Part Model (Felzenswalb, McAllester, Ramanan 2009)
#
# - PASCAL Visual Object Challenge (20 object categories)(Everingham et al 2006-2012)
#   - Contains 20 object classes
#
# - IMAGENET Large Scale Visual Recognition Challenge (1,000 object classes and 1.4 M images)
# - Russakovsky et al. arXiv (2014) - Convolutional Neural Network (2012 winning algorithm)
#
# ---
#
# # Image Recognition
# CS231n focusess on one of the most important problems of visual recognition -
# - Object detection (person, hammer ...)
# - Action classification
# - Image captioning
# <br>
# Some breakthroughs
# - SuperVision (AlexNet) - Krizhevsky NIPS 2012
# - GoogLeNet (VGG)(2014)
# - MSRA, Residual Network by Microsoft Research Asia (2015)
#   - The architecture of LeCun et al (1998) & Krizhevsky et al. (2012) are similar to that of AlexNet.
#
# Hardware breakthrough
# - GPUs (# of transistors 10^9)
#
# <br>
#
# The quest for visual intelligence goes far beyond object recognition
# - the goal is to make machines see like people.
#
#
# Your visual system is much more powerful than just drawing boxes and classifying cats and dogs.
# - Semantic segmentation
# - Perceptual grouping
# - What are the recognised image/objects doing, what does it mean?
# Example of vision lab (visual Genome)
#   - Trying to capture the intricacies of the real world.
# - Describe the images:
#   - Tries to describe the the whole graphs of visual semantics (semantic concepts)
#   - Objct identity
#   - Object attribute
#   - Object relations
#   - Actions ocurring in the scene
#
# <br>
#
# Have some fun
# - image captioning using RNN
# - DeepDream, NeuralStyle
#
# Deep Learning (Goodfellow, Bengio, Courville)
